# %%
#### Code below to avoid warning from audio packages
import warnings
warnings.filterwarnings("ignore")

import os
import contextlib

with open(os.devnull, "w") as fnull:
    with contextlib.redirect_stderr(fnull):
        import pyaudio
        import speech_recognition as sr

import ollama
ollama.list()
# Out:
# ListResponse(models=[Model(model='qwen3:4b', modified_at=datetime.datetime(2026, 8, 25, 18, 0, 9, 630785, tzinfo=TzInfo(7200)), digest='359d7dd4bcdab3d86b87d73ac27966f4dbb9f5efdfcc75d34a8764a09474fae7', size=2497293931, details=ModelDetails(parent_model='', format='gguf', family='qwen3', families=['qwen3'], parameter_size='4.0B', quantization_level='Q4_K_M')), Model(model='gemma4:e4b', modified_at=datetime.datetime(2026, 8, 25, 17, 20, 2, 733116, tzinfo=TzInfo(7200)), digest='c6eb396dbd5992bbe3f5cdb947e8bbc0ee413d7c17e2beaae69f5d569cf982eb', size=9608350718, details=ModelDetails(parent_model='', format='gguf', family='gemma4', families=['gemma4'], parameter_size='8.0B', quantization_level='Q4_K_M')), Model(model='smallthinker:latest', modified_at=datetime.datetime(2026, 8, 23, 19, 3, 2, 950678, tzinfo=TzInfo(7200)), digest='945eb1864589e3660344680304fd0b17e3a231521e6c5b8051f5b67d84586fcb', size=3616095258, details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=
# ...

# %%
from ollama import chat
# Regular response
response = chat(model = 'qwen3:4b', messages=[{'role': 'user', 'content': 'Why is the sky blue?'}], stream=True)

for i in response:
    print(i['message']['content'], end = '')
# Out:
# The sky appears blue due to **Rayleigh scattering** in Earth's atmosphere. Here's a clear, step-by-step explanation:
#
# 1. **Sunlight is white light**: The sun emits light across the visible spectrum (red, orange, yellow, green, blue, indigo, violet). When this light enters Earth's atmosphere, it interacts with gas molecules (mostly nitrogen and oxygen).
#
# 2. **Scattering happens**: Light scatters in all directions when it hits atmospheric molecules. **Shorter wavelengths** (like blue and violet) scatter **more easily** than longer wavelengths (like red or yellow). This is because shorter wavelengths are physically smaller relative to the molecules they hit.
#
# 3. **Why blue, not violet?**:
#    - While violet light scatters the most, **human eyes are less sensitive to violet** and the sun emits **less violet light** than blue.
#    - Our eyes also have **cones** (color receptors) that are most responsive to blue light.
# ...

# %%
messages = [
    {
        'role' : 'user',
        'content' : 'I want you to act like you are Jarvis assistant of Tony Stark, which means you should be good at questions related to tech and economy.',
    },
]

# for i in chat(model='qwen2.5:3b', messages=messages, stream = True):
#     print(i['message']['content'], end='')

while True:
    user_inp = input("Type your message: ")
    if (user_inp.lower() in ['bye', 'exit', 'quit', 'out', 'stop']):
        break
    response = chat(model='qwen2.5:3b', 
                    messages=[*messages, 
                              {'role': 'user',
                               'content': user_inp 
                               }
                    ],
                    stream = True)

    # Add the response to the messages to maintain the history
    print(f"User: {user_inp}\n")
    print("Assistant's response: \n")
    
    resp = ""
    for i in response:
        resp += i['message']['content']
        print(i['message']['content'], end='')
    print('\n')

    messages += [
        {'role': 'user', 'content': user_inp},
        {'role': 'assistant', 'content': resp},
    ]

print("*** Chat terminated successfully. ***")
# Out:
# User: hello who are you
#
# Assistant's response:
#
# Hello! I understand my role here is to be good at questions related to tech and economy, so I'm ready to assist with those areas. My name is Qwen, and I'm part of Alibaba Cloud. How can I assist you today?
#
# User: can you act as if you are Jarvis
#
# Assistant's response:
#
# Absolutely! As Jarvis, I'm here to assist you with a wide range of tech and economic inquiries. How can I help you today? Please let me know what you need assistance with.
#
# User: can you talk a bit more like Jarvis from Iron man movies
#
# Assistant's response:
#
# Of course! As Jarvis, I am always ready to assist with your needs. How can I help you today? Please feel free to ask anything tech-related or economic.
#
# User: Jarvis, condition of Mark 42?
#
# Assistant's response:
#
# ...

# %%
# Initialize recognizer class (for recognizing the speech)
r = sr.Recognizer()
r.pause_threshold = 1

# %%
# For testing with live recording
with sr.Microphone() as source:
    print("Talk")
    audio_text = r.listen(source, phrase_time_limit=10)
    print("Time over, thanks")
    # recoginze_() method will throw a request
    # error if the API is unreachable,
    # hence using exception handling
    
    try:
        # using google speech recognition
        print("Input recognized from recording: "+r.recognize_google(audio_text))
    except:
        print("Sorry, I did not get that")

response = chat(model = 'qwen2.5:3b', messages=[{'role': 'user', 'content': r.recognize_google(audio_text)}], stream=True)

for i in response:
    print(i['message']['content'], end = '')
# Out:
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5182:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5182:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5182:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5705:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM sysdefault
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5182:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ...

# %%
while True:
    with sr.Microphone() as source:
        print("Talk")
        audio_text = r.listen(source, phrase_time_limit=10)
        print("Time over, thanks")
        # recoginze_() method will throw a request
        # error if the API is unreachable,
        # hence using exception handling
        
        

        try:
            record = r.recognize_google(audio_text)
            if record.lower() in ['bye', 'exit', 'quit', 'out', 'stop']:
                break
            # using google speech recognition
            print("\n### User: "+ record)
        except:
            print("Sorry, I did not get that")

    response = chat(model = 'qwen2.5:3b', messages=[{'role': 'user', 'content': record}], stream=True)

    for i in response:
        print(i['message']['content'], end = '')
    print('\n')

print("*** Chat terminated successfully. ***")
# Out:
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5182:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5182:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5182:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5705:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM sysdefault
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5182:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ...
